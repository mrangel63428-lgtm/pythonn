// %% [markdown]
// # 01. Testing y TDD en JavaScript
// Fundamentos de pruebas unitarias sin frameworks externos.

// %%
// Framework de Testing Minimalista (Patrón AAA: Arrange, Act, Assert)
class TestSuite {
    constructor(nombre) {
        this.nombre = nombre;
        this.tests = [];
        this.passed = 0;
        this.failed = 0;
    }
    
    assertEquals(actual, expected, mensaje) {
        const pass = actual === expected;
        this.tests.push({
            tipo: 'assertEquals',
            mensaje,
            pass,
            actual: String(actual),
            expected: String(expected)
        });
        pass ? this.passed++ : this.failed++;
        return pass;
    }
    
    assertTrue(condicion, mensaje) {
        return this.assertEquals(condicion, true, mensaje);
    }
    
    assertThrows(fn, mensaje) {
        try {
            fn();
            this.tests.push({tipo: 'assertThrows', mensaje, pass: false, error: 'No lanzó excepción'});
            this.failed++;
            return false;
        } catch(e) {
            this.tests.push({tipo: 'assertThrows', mensaje, pass: true, error: e.message});
            this.passed++;
            return true;
        }
    }
    
    report() {
        let html = `<h3>🧪 Test Suite: ${this.nombre}</h3>`;
        html += `<p style="color: ${this.failed === 0 ? 'green' : 'red'};">✓ ${this.passed} passed, ✗ ${this.failed} failed</p>`;
        html += '<table style="border-collapse: collapse; font-family: monospace; width: 100%;">';
        html += '<tr style="background: #f0f0f0;"><th>Estado</th><th>Test</th><th>Detalles</th></tr>';
        
        this.tests.forEach(t => {
            const color = t.pass ? '#d4edda' : '#f8d7da';
            const icon = t.pass ? '✓' : '✗';
            const detalle = !t.pass && t.actual ? `Expected: ${t.expected}, Got: ${t.actual}` : '';
            html += `<tr style="background: ${color};"><td>${icon}</td><td>${t.mensaje}</td><td>${detalle}</td></tr>`;
        });
        
        html += '</table>';
        return {"text/html": html};
    }
}

// Función bajo prueba: Validador de contraseñas según criterios de seguridad
function validarPassword(pwd) {
    if (typeof pwd !== 'string') throw new TypeError('Debe ser string');
    if (pwd.length < 8) return {valido: false, razon: 'Mínimo 8 caracteres'};
    if (!/[A-Z]/.test(pwd)) return {valido: false, razon: 'Debe contener mayúscula'};
    if (!/[0-9]/.test(pwd)) return {valido: false, razon: 'Debe contener número'};
    return {valido: true};
}

// Ejecutar tests
const suite = new TestSuite('Validación de Passwords');

// Tests positivos
suite.assertEquals(validarPassword("Hola1234").valido, true, "Password válida aceptada");

// Tests negativos
suite.assertEquals(validarPassword("hola1234").valido, false, "Rechaza sin mayúscula");
suite.assertEquals(validarPassword("HolaMundo").valido, false, "Rechaza sin número");
suite.assertEquals(validarPassword("Ho1").valido, false, "Rechaza muy corta");

// Test de excepciones
suite.assertThrows(() => validarPassword(123), "Lanza error si no es string");

// Reporte
suite.report();

// %%
// Ejercicio: Implementar TDD para función calculadora con validación de tipos

function calculadora(a, b, operacion) {
    // Tu implementación aquí siguiendo TDD
    // Debe soportar: '+', '-', '*', '/'
    // Lanza error si operandos no son números
    // Maneja división por cero
}

const calcTests = new TestSuite('Calculadora Segura');

// Escribe tus tests primero, luego la implementación
calcTests.assertEquals(calculadora(2, 3, '+'), 5, "Suma básica");
// ... más tests

calcTests.report();
